# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadzacky447-blip/Pemerograman-Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata saya

nama = 'Ahmad Zacky'
umur = 21
jurusan = "TRPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False
tempat_tinggal = 'Batu Aji'
agama = 'Islam'
status = 'Lajang'

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (tempat_tinggal)
print (agama)
print (status)
# Out:
# Ahmad Zacky
# 21
# TRPE
# 3
# Pemerograman Dasar
# False
# Batu Aji
# Islam
# Lajang
